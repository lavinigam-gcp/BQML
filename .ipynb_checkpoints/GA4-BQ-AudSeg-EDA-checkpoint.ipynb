# %%
# !pip install plotly.express

# %% [markdown]
# Column Definations available here -
# https://support.google.com/analytics/answer/7029846#zippy=

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
from google.cloud import bigquery
client = bigquery.Client()

# %%
# %pwd 
# %cd /home/jupyter/BQML
# Out:
# /home/jupyter/BQML

# %%
import bq_helper_functions

# %%
project_id='bigquery-public-data'
dataset_id= 'ga4_obfuscated_sample_ecommerce'

# %%
# %%time 

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id)
df , query = bq_helper_functions.get_data_shape(table_params)
print(query)
df
# Out:
# SELECT count(distinct column_name), (select  count(*) from  `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`) FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
# CPU times: user 55 ms, sys: 5.96 ms, total: 61 ms
# Wall time: 4.52 s
#    Total Columns  Total Rows
# 0             23     4295584

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id)
df , query = bq_helper_functions.get_topN_data_from_table(2, table_params,all_tables=True)
print(query)
df
# Out:
# SELECT * FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*` LIMIT 2
# CPU times: user 47.4 ms, sys: 8.67 ms, total: 56.1 ms
# Wall time: 4.9 s
#   event_date   event_timestamp   event_name  \
# 0   20210101  1609468318563156  first_visit
# 1   20210101  1609468318563156    page_view
#
#                                         event_params  \
# 0  [{'key': 'ga_session_number', 'value': {'strin...
# 1  [{'key': 'page_location', 'value': {'string_va...
#
#    event_previous_timestamp  event_value_in_usd  event_bundle_sequence_id  \
# 0                       NaN                 NaN                1177212143
# 1                       NaN                 NaN                1177212143
#
#    event_server_timestamp_offset user_id      user_pseudo_id  \
# 0                            NaN    None  1003046.9452926974
# 1                            NaN    None  1003046.9452926974
#
#                                         privacy_info user_properties  \
# ...

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id)
df , query = bq_helper_functions.get_all_tables_in_dataset(table_params)
print(query)
df
# Out:
# SELECT TABLE_NAME from `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.TABLES`
# CPU times: user 37.5 ms, sys: 8.32 ms, total: 45.8 ms
# Wall time: 2.01 s
#          TABLE_NAME
# 0   events_20210109
# 1   events_20201109
# 2   events_20210110
# 3   events_20210123
# 4   events_20201107
# ..              ...
# 87  events_20210116
# 88  events_20201119
# 89  events_20201125
# 90  events_20201118
# 91  events_20201202
#
# [92 rows x 1 columns]

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id)
df, query = bq_helper_functions.get_table_metadata(table_params)
print(query)
df
# Out:
# SELECT * FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.__TABLES__`
# CPU times: user 38.2 ms, sys: 6.1 ms, total: 44.3 ms
# Wall time: 2.03 s
#               project_id                       dataset_id         table_id  \
# 0   bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20201101
# 1   bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20201102
# 2   bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20201103
# 3   bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20201104
# 4   bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20201105
# ..                   ...                              ...              ...
# 87  bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20210127
# 88  bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20210128
# 89  bigquery-public-data  ga4_obfuscated_sample_ecommerce  events_20210129
# ...

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id,'events_20201119')
df , query = bq_helper_functions.get_datatypes_of_column(table_params) #table name is required
print(query)
df
# Out:
# SELECT column_name,ordinal_position, is_nullable,data_type FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS` WHERE table_name = 'events_20201119'
# CPU times: user 40.3 ms, sys: 5.42 ms, total: 45.7 ms
# Wall time: 2.04 s
#                       column_name  ordinal_position is_nullable  \
# 0                      event_date                 1         YES
# 1                 event_timestamp                 2         YES
# 2                      event_name                 3         YES
# 3                    event_params                 4          NO
# 4        event_previous_timestamp                 5         YES
# 5              event_value_in_usd                 6         YES
# 6        event_bundle_sequence_id                 7         YES
# 7   event_server_timestamp_offset                 8         YES
# 8                         user_id                 9         YES
# 9                  user_pseudo_id                10         YES
# ...

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id,'events_20201119')
df , query = bq_helper_functions.get_datatypes_of_column(table_params,specific_type="FLOAT64") #table name is required
print(query)
df
# Out:
# SELECT column_name,ordinal_position, is_nullable,data_type FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS` WHERE table_name = 'events_20201119' AND data_type like 'FLOAT64'
# CPU times: user 54.1 ms, sys: 8.36 ms, total: 62.5 ms
# Wall time: 2.33 s
#           column_name  ordinal_position is_nullable data_type
# 0  event_value_in_usd                 6         YES   FLOAT64

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id,'events_20201119')
df , query = bq_helper_functions.get_datatypes_of_column(table_params,specific_type="INT64") #table name is required
print(query)
df
# Out:
# SELECT column_name,ordinal_position, is_nullable,data_type FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS` WHERE table_name = 'events_20201119' AND data_type like 'INT64'
# CPU times: user 40.9 ms, sys: 5.54 ms, total: 46.4 ms
# Wall time: 2 s
#                      column_name  ordinal_position is_nullable data_type
# 0                event_timestamp                 2         YES     INT64
# 1       event_previous_timestamp                 5         YES     INT64
# 2       event_bundle_sequence_id                 7         YES     INT64
# 3  event_server_timestamp_offset                 8         YES     INT64
# 4     user_first_touch_timestamp                13         YES     INT64
# 5                      stream_id                19         YES     INT64

# %%
# %%bigquery
#
# DECLARE query STRING;
# DECLARE columns ARRAY<STRING>;
# # get all the specific columns in an array
# SET columns = (
#   WITH all_columns AS (
#     SELECT column_name
#     FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
#     WHERE table_name = 'events_20210128'
#     and  data_type IN ('INT64','FLOAT64')
#   )
#   SELECT ARRAY_AGG((column_name) ) AS columns
#   FROM all_columns
# );
#
# SET query = (select STRING_AGG(x) from unnest(columns) as x);
#
# EXECUTE IMMEDIATE
# "select count(distinct(" || query || " from `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210128`";
# Out:
# ...
# Downloading: 100%|██████████| 43131/43131 [00:01<00:00, 40403.71rows/s]
#         event_timestamp  event_previous_timestamp  event_value_in_usd  \
# 0      1611795486890030                       NaN                 NaN
# 1      1611795491901996                       NaN                 NaN
# 2      1611795486890030                       NaN                 NaN
# 3      1611795516861652                       NaN                 NaN
# 4      1611795486890030                       NaN                 NaN
# ...                 ...                       ...                 ...
# 43126  1611854492830181                       NaN                 NaN
# 43127  1611875810983286                       NaN                 NaN
# 43128  1611805642520632                       NaN                 NaN
# 43129  1611805694112606                       NaN                 NaN
# 43130  1611825247053170                       NaN                 NaN
#
# ...

# %%
# %%bigquery
# DECLARE query STRING;
# DECLARE count INT64;
# DECLARE columns ARRAY<STRING>;
# # get all the specific columns in an array
# SET columns = (
#   WITH all_columns AS (
#     SELECT column_name
#     FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
#     WHERE table_name = 'events_20210128'
#     and  data_type IN ('INT64','FLOAT64')
#   )
#   SELECT ARRAY_AGG((column_name) ) AS columns
#   FROM all_columns
# );
#
# set count = (SELECT
#     COUNT(*)
#   FROM
#     bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210128);
#
# set query = (select STRING_AGG('ROUND(COUNT(DISTINCT ' ||x||")/"||count||",2)*100  as "||x||'_prcntg')
#             from unnest(columns) as x);
# EXECUTE IMMEDIATE
#   "SELECT  "|| query || ' from `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210128`';
# Out:
# ...
# Downloading: 100%|██████████| 1/1 [00:01<00:00,  1.08s/rows]
#    event_timestamp_prcntg  event_previous_timestamp_prcntg  \
# 0                    64.0                              0.0
#
#    event_value_in_usd_prcntg  event_bundle_sequence_id_prcntg  \
# 0                        0.0                             64.0
#
#    event_server_timestamp_offset_prcntg  user_first_touch_timestamp_prcntg  \
# 0                                   0.0                                8.0
#
#    stream_id_prcntg
# 0               0.0

# %%
SELECT  
COUNT(DISTINCT event_timestamp) ,
COUNT(DISTINCT event_previous_timestamp) ,
COUNT(DISTINCT event_value_in_usd) ,
COUNT(DISTINCT event_bundle_sequence_id) ,
COUNT(DISTINCT event_server_timestamp_offset) ,
COUNT(DISTINCT user_first_touch_timestamp) ,
COUNT(DISTINCT stream_id) 
from `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210128`

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id,'events_20201119')
df , query = bq_helper_functions.get_datatypes_of_column(table_params,specific_type="STRING") #table name is required
print(query)
df
# Out:
# SELECT column_name,ordinal_position, is_nullable,data_type FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS` WHERE table_name = 'events_20201119' AND data_type like 'STRING'
# CPU times: user 40.8 ms, sys: 4.78 ms, total: 45.6 ms
# Wall time: 1.87 s
#       column_name  ordinal_position is_nullable data_type
# 0      event_date                 1         YES    STRING
# 1      event_name                 3         YES    STRING
# 2         user_id                 9         YES    STRING
# 3  user_pseudo_id                10         YES    STRING
# 4        platform                20         YES    STRING

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id,'events_20201119')
df , query = bq_helper_functions.get_datatypes_of_column(table_params,specific_type="ARRAY") #table name is required
print(query)
df
# Out:
# SELECT column_name,ordinal_position, is_nullable,data_type FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS` WHERE table_name = 'events_20201119' AND data_type like 'ARRAY%'
# CPU times: user 52.8 ms, sys: 10.1 ms, total: 62.9 ms
# Wall time: 2.07 s
#        column_name  ordinal_position is_nullable  \
# 0     event_params                 4          NO
# 1  user_properties                12          NO
# 2            items                23          NO
#
#                                            data_type
# 0  ARRAY<STRUCT<key STRING, value STRUCT<string_v...
# 1  ARRAY<STRUCT<key INT64, value STRUCT<string_va...
# 2  ARRAY<STRUCT<item_id STRING, item_name STRING,...

# %%
# %%time

table_params = bq_helper_functions.get_table_detail_dict(project_id,dataset_id,'events_20201119')
df , query = bq_helper_functions.get_datatypes_of_column(table_params,specific_type="STRUCT") #table name is required
print(query)
df
# Out:
# SELECT column_name,ordinal_position, is_nullable,data_type FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS` WHERE table_name = 'events_20201119' AND data_type like 'STRUCT%%'
# CPU times: user 35.9 ms, sys: 8.71 ms, total: 44.6 ms
# Wall time: 2.03 s
#         column_name  ordinal_position is_nullable  \
# 0      privacy_info                11         YES
# 1          user_ltv                14         YES
# 2            device                15         YES
# 3               geo                16         YES
# 4          app_info                17         YES
# 5    traffic_source                18         YES
# 6  event_dimensions                21         YES
# 7         ecommerce                22         YES
#
#                                            data_type
# 0  STRUCT<analytics_storage INT64, ads_storage IN...
# 1           STRUCT<revenue FLOAT64, currency STRING>
# 2  STRUCT<category STRING, mobile_brand_name STRI...
# ...

# %%
# %%bigquery
#
# DECLARE query STRING;
# DECLARE columns ARRAY<STRING>;
# # get all the specific columns in an array
# SET columns = (
#   WITH all_columns AS (
#     SELECT column_name
#     FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
#     WHERE table_name = 'events_20210128'
#     and  data_type LIKE 'ARRAY%'
#       # OR data_type LIKE 'STRUCT%'
#   )
#   SELECT ARRAY_AGG((column_name) ) AS columns
#   FROM all_columns
# );
#
# SET query = (select STRING_AGG(x) from unnest(columns) as x);
#
# EXECUTE IMMEDIATE
# "select " || query || " from `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210128`";
# Out:
# ...
# Downloading: 100%|██████████| 43131/43131 [00:01<00:00, 34061.33rows/s]
#                                             event_params user_properties  \
# 0      [{'key': 'page_location', 'value': {'string_va...              []
# 1      [{'key': 'engagement_time_msec', 'value': {'st...              []
# 2      [{'key': 'ga_session_number', 'value': {'strin...              []
# 3      [{'key': 'engaged_session_event', 'value': {'s...              []
# 4      [{'key': 'session_engaged', 'value': {'string_...              []
# ...                                                  ...             ...
# 43126  [{'key': 'page_location', 'value': {'string_va...              []
# 43127  [{'key': 'debug_mode', 'value': {'string_value...              []
# 43128  [{'key': 'page_title', 'value': {'string_value...              []
# 43129  [{'key': 'engagement_time_msec', 'value': {'st...              []
# 43130  [{'key': 'ga_session_id', 'value': {'string_va...              []
#
# ...

# %%
# %%bigquery
#
# DECLARE query STRING;
# DECLARE columns ARRAY<STRING>;
# # get all the specific columns in an array
# SET columns = (
#   WITH all_columns AS (
#     SELECT column_name
#     FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
#     WHERE table_name = 'events_20210128'
#     # and  data_type LIKE 'ARRAY%'
#     and data_type LIKE 'STRUCT%'
#   )
#   SELECT ARRAY_AGG((column_name) ) AS columns
#   FROM all_columns
# );
#
# SET query = (select STRING_AGG(x) from unnest(columns) as x);
#
# EXECUTE IMMEDIATE
# "select " || query || " from `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_20210128`";
# Out:
# ...
# Downloading: 100%|██████████| 43131/43131 [00:01<00:00, 35078.13rows/s]
#                                             privacy_info  \
# 0      {'analytics_storage': None, 'ads_storage': Non...
# 1      {'analytics_storage': None, 'ads_storage': Non...
# 2      {'analytics_storage': None, 'ads_storage': Non...
# 3      {'analytics_storage': None, 'ads_storage': Non...
# 4      {'analytics_storage': None, 'ads_storage': Non...
# ...                                                  ...
# 43126  {'analytics_storage': None, 'ads_storage': Non...
# 43127  {'analytics_storage': None, 'ads_storage': Non...
# 43128  {'analytics_storage': None, 'ads_storage': Non...
# 43129  {'analytics_storage': None, 'ads_storage': Non...
# 43130  {'analytics_storage': None, 'ads_storage': Non...
#
#                                     user_ltv  \
# 0        {'revenue': 0.0, 'currency': 'USD'}
# 1        {'revenue': 0.0, 'currency': 'USD'}
# 2        {'revenue': 0.0, 'currency': 'USD'}
# ...

# %%
# %%bigquery
# # All the ARRAY Structure Columns
# SELECT
#     column_name,ordinal_position,
#     is_nullable,data_type
# FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
# WHERE table_name = 'events_20210116'
# AND data_type like 'ARRAY%'

# %%
# %%bigquery
# # All the Struct Structure Columns
# SELECT
#     column_name,ordinal_position,
#     is_nullable,data_type
# FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
# WHERE table_name = 'events_20210116'
# AND data_type like 'STRUCT%'

# %%
# %%bigquery
# SELECT
#     privacy_info,user_ltv,device,
#     geo,app_info,app_info,traffic_source,
#     event_dimensions,ecommerce
# FROM
#     `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`
# LIMIT 2

# %%
# %%bigquery
# SELECT
#     privacy_info.key as key
# FROM
#     `bigquery-public-data.ga4_obfuscated_sample_ecommerce.events_*`,
#     UNNEST(privacy_info) as privacy_info
# LIMIT 2

# %%
# %%bigquery
# # All the STRING, INT64 Columns
# SELECT
#     column_name,ordinal_position,
#     is_nullable,data_type
# FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
# WHERE table_name = 'events_20210116'
# AND data_type not like 'STRUCT%'
# AND data_type not like 'ARRAY%'

# %%
query = """
SELECT 
    column_name,ordinal_position,
    is_nullable,data_type
FROM `bigquery-public-data.ga4_obfuscated_sample_ecommerce.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'events_20210116'
"""
df = get_df_from_query(query)

# %%
df.head()

# %%
df[df['data_type'].str.startswith('ARRAY', na=False)]

# %%
df[df['column_name']=='event_params']['data_type'].iloc[0]

# %%
df[df['column_name']=='event_params']['data_type'].iloc[0].split(' ')
